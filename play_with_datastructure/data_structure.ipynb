# %% [markdown]
# ![](extract_spiketrain_for_one_unit.png)

# %% [markdown]
# ### Below is a simple class function using the available functions in neo. This function make the extraction of spike more intuitive.

# %%
# a class function for extracting spike trains from desired unit of a channel in a specified trial-type
class FromDataBlock(object):
    def __init__(self,data_block):
        self.data_block = data_block
        self.total_electrodes = len(data_block.channel_indexes)
        self.total_trial_no = len(data_block.segments)
        self.list_of_trials = []
    
    def extract_spiketrains_for_desired_trialtype_connectid(self, desired_trial_type, connect_id):
        spktrain = data_block.filter( targdict={'belongs_to_trialtype': desired_trial_type,
                                                'connector_aligned_id': connect_id},
                                      objects=neo.SpikeTrain )
        if spktrain == []:
            print ("This connection ID has no recording of the spike train. Choose another connector ID.")
        else:
            return spktrain
        
    def extract_spiketrains_for_desired_unit(self, spktrain_for_desired_trialtype_connectid, unit_id):
            return [value for i, value in enumerate(spktrain_for_desired_trialtype_connectid)
                                if value.annotations['unit_id']==unit_id ]

# %%
# %%capture
import neo
import quantities as pq
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### For a desired dataset
# **A dataset is A neo Block**

# %%
path = './data/'
data_idx = 0
data_block = np.load(path + 'data{}.npy'.format(data_idx), encoding='latin1').item()

# %% [markdown]
# ### To extract desired spike train using the above class

# %%
extract_func = FromDataBlock(data_block) # instantiate the class

# %% [markdown]
# **Extract all spike trains from a desired channel for a particular trial type**

# %%
desired_trial_type = 'PGHF'
desired_channel = 1 # this is the electrode connection id aligned linearly

# %%
all_spiketrains = extract_func.extract_spiketrains_for_desired_trialtype_connectid(desired_trial_type, desired_channel)
# Out:
# This connection ID has no recording of the spike train. Choose another connector ID.

# %% [markdown]
# #### Recordings were not taken from all the channels (total 100)

# %%
desired_channel = 2

# %%
all_spiketrains = extract_func.extract_spiketrains_for_desired_trialtype_connectid(desired_trial_type, desired_channel)

# %%
all_spiketrains
# Out:
# [SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 6,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 6,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 16,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 16,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 17,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 17,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 21,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 21,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 22,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 22,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 23,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 23,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 24,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 24,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 25,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 25,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 28,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 28,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 33,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 33,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 40,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 40,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 48,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 48,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 51,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 51,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 53,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 53,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 57,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 57,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 58,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 58,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 71,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 71,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 74,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 74,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 75,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 75,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 81,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 81,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 82,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 82,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 101,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 101,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 102,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 102,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 105,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 105,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 106,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 106,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 112,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 112,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 129,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 129,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 131,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 131,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 133,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 133,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 134,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 134,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 135,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 135,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 144,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 144,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 148,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 148,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 152,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 152,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 153,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 153,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 157,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 157,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 1,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 1,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 2,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 2,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 8,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 8,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 13,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 13,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 15,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 15,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 39,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 39,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 41,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 41,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 42,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 42,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 45,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 45,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 46,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 46,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 49,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 49,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 50,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 50,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 54,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 54,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 63,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 63,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 65,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 65,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 66,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 66,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 69,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 69,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 70,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 70,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 73,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 73,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 79,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 79,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 84,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 84,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 92,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 92,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 99,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 99,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 103,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 103,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 108,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 108,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 111,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 111,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 114,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 114,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 116,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 116,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 117,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 117,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 118,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 118,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 120,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 120,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 137,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 137,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 140,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 140,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 141,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 141,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 146,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 146,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 149,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 149,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 9,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 9,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 14,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 14,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 18,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 18,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 19,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 19,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 20,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 20,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 26,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 26,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 29,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 29,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 30,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 30,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 43,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 43,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 44,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 44,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 56,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 56,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 62,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 62,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 64,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 64,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 67,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 67,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 68,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 68,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 76,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 76,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 77,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 77,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 80,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 80,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 86,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 86,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 88,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 88,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 91,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 91,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 96,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 96,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 97,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 97,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 98,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 98,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 100,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 100,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 119,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 119,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 123,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 123,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 125,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 125,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 127,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 127,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 130,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 130,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 138,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 138,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 139,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 139,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 147,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 147,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
# ...
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 4,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 4,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 5,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 5,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 10,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 10,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 11,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 11,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 12,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 12,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 27,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 27,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 35,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 35,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 36,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 36,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 37,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 37,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 38,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 38,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 47,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 47,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 52,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 52,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 55,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 55,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 60,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 60,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 61,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 61,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 83,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 83,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 85,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 85,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 87,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 87,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 89,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 89,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 90,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 90,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 93,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 93,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 94,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 94,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 104,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 104,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 109,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 109,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 113,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 113,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 121,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 121,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 122,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 122,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 124,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 124,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 128,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 128,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 132,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 132,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 136,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 136,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 145,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 145,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 158,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 158,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 160,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 160,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 161,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 161,
#    'unit_id': 1}]

# %% [markdown]
# ### Notice that these are all the spike trains from our desired channel for the chosen trial type
# **Thus for all the spike trains recording from a single unit, do the following**

# %%
neurons_per_channel = 1 # this is the unit id integer representing no of neurons responsible for the spike train

# %%
desired_spiketrain = extract_func.extract_spiketrains_for_desired_unit(all_spiketrains,neurons_per_channel)

# %%
desired_spiketrain
# Out:
# [SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 6,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 16,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 17,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 21,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 22,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 23,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 24,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 25,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 28,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 33,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 40,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 48,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 51,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 53,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 57,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 58,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 71,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 74,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 75,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 81,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 82,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 101,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 102,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 105,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 106,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 112,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 129,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 131,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 133,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 134,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 135,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 144,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 148,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 152,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 153,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 157,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 1,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 2,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 8,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 13,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 15,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 39,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 41,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 42,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 45,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 46,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 49,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 50,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 54,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 63,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 65,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 66,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 69,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 70,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 73,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 79,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 84,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 92,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 99,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 103,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 108,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 111,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 114,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 116,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 117,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 118,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 120,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 137,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 140,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 141,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 146,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 149,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 9,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 14,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 18,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 19,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 20,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 26,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 29,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 30,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 43,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 44,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 56,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 62,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 64,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 67,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 68,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 76,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 77,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 80,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 86,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 88,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 91,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 96,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 97,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 98,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 100,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 119,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 123,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 125,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 127,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 130,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 138,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 139,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 147,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 150,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 159,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 4,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 5,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 10,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 11,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 12,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 27,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 35,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 36,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 37,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 38,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 47,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 52,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 55,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 60,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 61,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 83,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 85,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 87,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 89,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 90,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 93,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 94,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 104,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 109,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 113,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 121,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 122,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 124,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 128,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 132,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 136,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 145,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 158,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 160,
#    'unit_id': 1},
#  SpikeTrain
#  annotations: {'SNR': 5.80501307302,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 671.276473167,
#    'sua': True,
#    'trial_id_st': 161,
#    'unit_id': 1}]

# %% [markdown]
# ![](extract_spiketrain_for_two_units.png)

# %% [markdown]
# #### Therefore for spiketrains from another unit

# %%
neurons_per_channel2 = 2 # there are 4 in total for our dataset

# %%
desired_spiketrain2 = extract_func.extract_spiketrains_for_desired_unit(all_spiketrains,neurons_per_channel2)

# %%
desired_spiketrain2
# Out:
# [SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 6,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 16,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 17,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 21,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 22,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 23,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 24,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 25,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 28,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 33,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 40,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 48,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 51,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 53,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 57,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 58,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 71,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 74,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 75,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 81,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 82,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 101,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 102,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 105,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 106,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 112,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 129,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 131,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 133,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 134,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 135,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 144,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 148,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 152,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 153,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 157,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 1,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 2,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 8,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 13,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 15,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 39,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 41,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 42,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 45,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 46,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 49,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 50,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 54,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 63,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 65,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 66,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 69,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 70,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 73,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 79,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 84,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 92,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 99,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 103,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 108,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 111,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 114,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 116,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 117,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 118,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 120,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 137,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 140,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 141,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 146,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGHF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 149,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 9,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 14,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 18,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 19,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 20,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 26,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 29,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 30,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 43,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 44,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 56,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 62,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 64,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 67,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 68,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 76,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 77,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 80,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 86,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 88,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 91,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 96,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 97,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 98,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 100,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 119,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 123,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 125,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 127,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 130,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 138,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 139,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 147,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 150,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'PGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 159,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 4,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 5,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 10,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 11,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 12,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 27,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 35,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 36,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 37,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 38,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 47,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 52,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 55,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 60,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 61,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 83,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 85,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 87,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 89,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 90,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 93,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 94,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 104,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 109,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 113,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 121,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 122,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 124,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 128,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 132,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 136,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 145,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 158,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 160,
#    'unit_id': 2},
#  SpikeTrain
#  annotations: {'SNR': 3.29836784284,
#    'belong_to_trialtype': u'SGLF',
#    'channel_id': 81,
#    'connector_aligned_id': 2,
#    'spike_amplitude': 397.600210383,
#    'sua': True,
#    'trial_id_st': 161,
#    'unit_id': 2}]
